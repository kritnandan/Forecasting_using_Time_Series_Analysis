# %%
#import all libraries which is required for handling the dataset and loading the dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
url = "https://raw.githubusercontent.com/FuTSA23/time-series-analysis-datasets/main/Complete_Blasting_info%20(1).csv"
df = pd.read_csv(url)
df
# Out:
#       Unnamed: 0  PM10 (µg/m3)      Time        Date  NO (µg/m3)
# 0              0          95.0  00:00:00  2023-02-01   14.484070  \
# 1              1          95.0  00:15:00  2023-02-01   14.484070
# 2              2          95.0  00:30:00  2023-02-01   15.835914
# 3              3         122.0  00:45:00  2023-02-01   15.914518
# 4              4         122.0  01:00:00  2023-02-01   16.035640
# ...          ...           ...       ...         ...         ...
# 8635        8635          19.0  22:45:00  2023-05-01   17.900000
# 8636        8636          19.0  23:00:00  2023-05-01   17.900000
# 8637        8637          19.0  23:15:00  2023-05-01   19.600000
# 8638        8638          19.0  23:30:00  2023-05-01   20.800000
# 8639        8639          32.0  23:45:00  2023-05-01   21.800000
#
#       PM2.5 (µg/m3)  NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)
# 0              35.0         90.1       56.2    0.310000    11.986833  \
# 1              35.0         88.0       55.1    0.330000    11.986833
# 2              35.0         87.7       55.2    0.380000    10.912796
# 3              34.0         88.9       55.7    0.380000    10.613291
# 4              34.0         90.0       55.8    0.380000     7.362361
# ...             ...          ...        ...         ...          ...
# 8635           11.0        100.0       67.8    0.630000    10.000000
# 8636           11.0        100.0       67.7    0.570000    10.000000
# 8637           11.0        100.2       69.2    0.580000     9.900000
# 8638           11.0        100.2       70.2    0.580000     9.500000
# 8639            6.0         98.8       70.3    0.883181    13.054913
#
#       NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)
# 0            17.7           28.1              0.4
# 1            18.3           27.1              0.4
# 2            19.7           24.9              0.4
# 3            21.3           21.9              0.4
# 4            22.3           16.7              0.4
# ...           ...            ...              ...
# 8635         10.7           26.1              0.1
# 8636         10.4           30.9              0.1
# 8637         10.5           29.6              0.1
# 8638         10.8           30.0              0.1
# 8639         11.0           33.5              0.1
#
# [8640 rows x 13 columns]

# %%
# finding the information about the columns of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640 entries, 0 to 8639
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       8640 non-null   int64
#  1   PM10 (µg/m3)     8640 non-null   float64
#  2   Time             8640 non-null   object
#  3   Date             8640 non-null   object
#  4   NO (µg/m3)       8640 non-null   float64
#  5   PM2.5 (µg/m3)    8640 non-null   float64
#  6   NO2 (µg/m3)      8640 non-null   float64
#  7   NOX (ppb)        8640 non-null   float64
#  8   CO (mg/m3)       8640 non-null   float64
#  9   SO2 (µg/m3)      8640 non-null   float64
#  10  NH3 (µg/m3)      8640 non-null   float64
#  11  Ozone (µg/m3)    8640 non-null   float64
#  12  Benzene (µg/m3)  8640 non-null   float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 877.6+ KB

# %%
# finding the staticals data of the dataset
df.describe()
# Out:
#         Unnamed: 0  PM10 (µg/m3)   NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)
# count  8640.000000   8640.000000  8640.000000    8640.000000  8640.000000  \
# mean   4319.500000    165.140621    14.269630      74.626459    56.128353
# std    2494.297496    128.089107    17.986445      54.992383    20.328553
# min       0.000000    -13.488183     0.100000       3.000000     0.200000
# 25%    2159.750000     79.000000     4.000000      36.000000    39.575000
# 50%    4319.500000    127.000000     6.600000      59.000000    53.800000
# 75%    6479.250000    208.000000    17.121285     100.000000    71.500000
# max    8639.000000    847.000000   157.500000     474.000000   106.900000
#
#          NOX (ppb)   CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  Ozone (µg/m3)
# count  8640.000000  8640.000000  8640.000000  8640.000000    8640.000000  \
# mean     42.457154     1.392857    33.727472    13.160495      35.765681
# std      22.129798     0.626985    38.878154     6.095797      26.549469
# min       4.200000     0.100000     0.100000     4.600000       0.100000
# 25%      25.100000     0.930000    15.000000     9.400000      11.000000
# 50%      37.500000     1.390000    24.200000    11.000000      33.000000
# 75%      53.300000     1.832500    36.100000    13.900000      58.125000
# max     165.200000     4.000000   645.600000    62.400000     123.800000
#
#        Benzene (µg/m3)
# count      8640.000000
# mean          0.177505
# std           0.052601
# min           0.100000
# 25%           0.177505
# 50%           0.177505
# 75%           0.177505
# max           0.600000

# %%
# finding the number of null value present in the every columns
df.isnull().sum()
# Out:
# Unnamed: 0         0
# PM10 (µg/m3)       0
# Time               0
# Date               0
# NO (µg/m3)         0
# PM2.5 (µg/m3)      0
# NO2 (µg/m3)        0
# NOX (ppb)          0
# CO (mg/m3)         0
# SO2 (µg/m3)        0
# NH3 (µg/m3)        0
# Ozone (µg/m3)      0
# Benzene (µg/m3)    0
# dtype: int64

# %%
# here applying the linear interpolatetion
df_linear = df.interpolate(method='linear')
df['Date'] = pd.to_datetime(df['Date'])
df['Time'] = pd.to_datetime(df['Time'])
print(df.dtypes)
# Out:
# Unnamed: 0                  int64
# PM10 (µg/m3)              float64
# Time               datetime64[ns]
# Date               datetime64[ns]
# NO (µg/m3)                float64
# PM2.5 (µg/m3)             float64
# NO2 (µg/m3)               float64
# NOX (ppb)                 float64
# CO (mg/m3)                float64
# SO2 (µg/m3)               float64
# NH3 (µg/m3)               float64
# Ozone (µg/m3)             float64
# Benzene (µg/m3)           float64
# dtype: object
# C:\Users\HP\AppData\Local\Temp\ipykernel_23888\4005583964.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import LSTM, Dense
#model = Sequential()
#model.add(LSTM(64, input_shape=(Time, num_features))) 
#model.add(Dense(num_classes, activation='softmax'))
#model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size)
#evaluation_metrics = model.evaluate(X_test, y_test)
#print("Test Accuracy:", evaluation_metrics[1])

# %%
# analyzing the dataset by the graph between PM10 columns and PM2.5 columns 
plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['PM10 (µg/m3)'], label='PM10')
plt.plot(df['Date'], df['PM2.5 (µg/m3)'], label='PM2.5')
plt.xlabel('Date')
plt.ylabel('Concentration (µg/m3)')
plt.title('PM10 and PM2.5 Time Series')
plt.legend()
plt.show()

# %%
# analyzing the dataset by the graph among NO ,NO2 and NOX 
plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['NO (µg/m3)'], label='NO')
plt.plot(df['Date'], df['NO2 (µg/m3)'], label='NO2')
plt.plot(df['Date'], df['NOX (ppb)'], label='NOX')
plt.xlabel('Date')
plt.ylabel('Concentration (µg/m3 or ppb)')
plt.title('NO, NO2, and NOX Time Series')
plt.legend()
plt.show()

# %%
# analyzing the dataset by the graph among CO ,SO2 and NH3
plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['CO (mg/m3)'], label='CO')
plt.plot(df['Date'], df['SO2 (µg/m3)'], label='SO2')
plt.plot(df['Date'], df['NH3 (µg/m3)'], label='NH3')
plt.xlabel('Date')
plt.ylabel('Concentration (µg/m3 or mg/m3 )')
plt.title('CO, SO2, and NH3 Time Series')
plt.legend()
plt.show()

# %%
# analyzing the dataset by the between ozone and benzene columns
plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['Ozone (µg/m3)'], label='Ozone')
plt.plot(df['Date'], df['Benzene (µg/m3)'], label='Benzene')
plt.xlabel('Date')
plt.ylabel('Concentration (µg/m3 or mg/m3 )')
plt.title('Ozone and Benzene Time Series')
plt.legend()
plt.show()

# %%
# in this part fit the dataset and work on the smoothing of the curve
from scipy.interpolate import UnivariateSpline
from scipy.stats import norm
time = np.arange(len(df))
pm10 = df['PM10 (µg/m3)']
pm25 = df['PM2.5 (µg/m3)']
no = df['NO (µg/m3)']
no2 = df['NO2 (µg/m3)']
nox = df['NOX (ppb)']
co = df['CO (mg/m3)'] 
so2 = df['SO2 (µg/m3)']
nh3 = df['NH3 (µg/m3)']
ozone = df['Ozone (µg/m3)']
benzene = df['Benzene (µg/m3)']
smooth_pm10 = UnivariateSpline(time, pm10, s=100)
smooth_pm25 = UnivariateSpline(time, pm25, s=100)
smooth_no = UnivariateSpline(time, no, s=100)
smooth_no2 = UnivariateSpline(time, no2, s=100)
smooth_nox = UnivariateSpline(time, nox, s=100)
smooth_co = UnivariateSpline(time, co, s=100)
smooth_so2 = UnivariateSpline(time, so2, s=100)
smooth_nh3 = UnivariateSpline(time, nh3, s=100)
smooth_ozone = UnivariateSpline(time, ozone, s=100)
smooth_benzene = UnivariateSpline(time, benzene, s=100)
parametric_fit_pm10 = norm.fit(pm10)
parametric_fit_pm25 = norm.fit(pm25)
parametric_fit_no = norm.fit(no)
parametric_fit_no2 = norm.fit(no2)
parametric_fit_nox = norm.fit(nox)
parametric_fit_co = norm.fit(co)
parametric_fit_so2 = norm.fit(so2)
parametric_fit_nh3 = norm.fit(nh3)
parametric_fit_ozone = norm.fit(ozone)
parametric_fit_benzene = norm.fit(benzene)
plt.figure(figsize=(14, 8))
plt.plot(time, smooth_pm10(time), label='PM10 (Smoothed)')
plt.plot(time, smooth_pm25(time), label='PM2.5 (Smoothed)')
plt.plot(time, smooth_no(time), label='NO (Smoothed)')
plt.plot(time, smooth_no2(time), label='NO2 (Smoothed)')
plt.plot(time, smooth_nox(time), label='NOX (Smoothed)')
plt.plot(time, smooth_co(time), label='CO (moothed)')
plt.plot(time, smooth_so2(time), label='SO2 (Smoothed)')
plt.plot(time, smooth_nh3(time), label='NH3 (Smoothed)')
plt.plot(time, smooth_ozone(time), label='OZONE (Smoothed)')
plt.plot(time, smooth_benzene(time), label='BENZENE (Smoothed)')
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title('Air Pollution Data along Curves')
plt.legend()
plt.show()

# %%
# in this part fit the data set by using the gaussian method 
plt.plot(time, norm.pdf(time, *parametric_fit_pm10), label='PM10 (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_pm25), label='PM2.5 (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_no), label='NO (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_no2), label='NO2 (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_nox), label='NOX (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_co), label='CO (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_so2), label='SO2 (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_nh3), label='NH3 (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_ozone), label='OZONE (Gaussian Fit)')
plt.plot(time, norm.pdf(time, *parametric_fit_benzene), label='BENZENE (Gaussian Fit)')
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title('Air Pollution Data along Curves')
plt.legend()
plt.show()

# %%
# in this part getting the descriptive analysis by finding the frequency during the time of balsting for the every columns
df = pd.DataFrame(df)
blasting_period_start = '13:45:00'
blasting_period_end = '14:45:00'
df['Time'] = pd.to_datetime(df['Time'])
blasting_data = df[(df['Time'] >= blasting_period_start) & (df['Time'] <= blasting_period_end)]
pm10_frequency = blasting_data['PM10 (µg/m3)'].value_counts()
pm2not5_frequency = blasting_data['PM2.5 (µg/m3)'].value_counts()
no_frequency = blasting_data['NO (µg/m3)'].value_counts()
no2_frequency = blasting_data['NO2 (µg/m3)'].value_counts()
nox_frequency = blasting_data['NOX (ppb)'].value_counts()
co_frequency = blasting_data['CO (mg/m3)'].value_counts()
so2_frequency = blasting_data['SO2 (µg/m3)'].value_counts()
nh3_frequency = blasting_data['NH3 (µg/m3)'].value_counts()
ozone_frequency = blasting_data['Ozone (µg/m3)'].value_counts()
benzene_frequency = blasting_data['Benzene (µg/m3)'].value_counts()
print(pm10_frequency)
print(pm2not5_frequency)
print(no_frequency)
print(no2_frequency)
print(nox_frequency)
print(co_frequency)
print(so2_frequency)
print(nh3_frequency)
print(ozone_frequency)
print(benzene_frequency)
# Out:
# PM10 (µg/m3)
# 43.042385     19
# 32.928895     19
# 60.705781     19
# 70.997488     19
# 68.691900     19
#               ..
# 74.000000      1
# 99.000000      1
# 78.000000      1
# 166.000000     1
# 39.000000      1
# Name: count, Length: 90, dtype: int64
# PM2.5 (µg/m3)
# 30.0    26
# 32.0    20
# 24.0    16
# 20.0    15
# 38.0    15
#         ..
# 76.0     1
# 40.0     1
# 6.0      1
# 93.0     1
# 8.0      1
# Name: count, Length: 64, dtype: int64
# NO (µg/m3)
# 3.5     22
# 3.4     22
# 3.1     19
# 3.6     18
# 3.9     17
#         ..
# 31.7     1
# 7.4      1
# 4.9      1
# 13.2     1
# 2.1      1
# Name: count, Length: 96, dtype: int64
# NO2 (µg/m3)
# 27.900000    5
# 28.000000    5
# 28.400000    4
# 33.300000    4
# 29.500000    4
#             ..
# 86.800000    1
# 22.900000    1
# 24.500000    1
# 58.847335    1
# 82.500000    1
# Name: count, Length: 309, dtype: int64
# NOX (ppb)
# 17.8    9
# 18.1    9
# 17.2    8
# 17.0    8
# 17.7    8
#        ..
# 49.0    1
# 48.4    1
# 82.2    1
# 83.0    1
# 47.5    1
# Name: count, Length: 241, dtype: int64
# CO (mg/m3)
# 1.06    10
# 0.24     9
# 0.94     8
# 0.86     8
# 1.08     7
#         ..
# 2.32     1
# 1.50     1
# 1.43     1
# 1.42     1
# 0.11     1
# Name: count, Length: 155, dtype: int64
# SO2 (µg/m3)
# 49.421488    12
# 29.556898    12
# 53.211752    11
# 36.971376    11
# 27.448166    11
#              ..
# 74.100000     1
# 70.200000     1
# 68.700000     1
# 81.400000     1
# 37.800000     1
# Name: count, Length: 315, dtype: int64
# NH3 (µg/m3)
# 10.8    13
# 10.5    12
# 8.0     12
# 9.8     12
# 9.6     12
#         ..
# 26.6     1
# 33.7     1
# 18.1     1
# 18.8     1
# 13.6     1
# Name: count, Length: 149, dtype: int64
# Ozone (µg/m3)
# 74.4    5
# 75.7    4
# 74.8    4
# 62.5    4
# 71.6    4
#        ..
# 79.2    1
# 57.5    1
# 79.8    1
# 83.7    1
# 32.0    1
# Name: count, Length: 291, dtype: int64
# Benzene (µg/m3)
# 0.177505    324
# 0.100000    120
# 0.200000      6
# Name: count, dtype: int64

# %%
# in this part finding the cetral frequency , in the central frequency mean and median getting 
measures_of_central_tendency = blasting_data.agg(['mean', 'median', lambda x: x.mode().values[0]])
measures_of_central_tendency.head()
# Out:
#           Unnamed: 0  PM10 (µg/m3)                Time
# mean          4329.0     97.693250 2023-07-28 14:15:00  \
# median        4329.0     84.000000 2023-07-28 14:15:00
# <lambda>        55.0     32.928895 2023-07-28 13:45:00
#
#                                   Date  NO (µg/m3)  PM2.5 (µg/m3)
# mean     2023-03-17 11:59:59.999999744    5.490348      34.181804  \
# median   2023-03-17 12:00:00.000000000    3.900000      31.000000
# <lambda> 2023-02-01 00:00:00.000000000    3.400000      30.000000
#
#           NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)
# mean        47.803924  29.993426    1.055087    51.798855    12.715081  \
# median      42.150000  25.950000    0.965000    30.300000    10.100000
# <lambda>    27.900000  17.800000    1.060000    29.556898    10.800000
#
#           Ozone (µg/m3)  Benzene (µg/m3)
# mean          66.428793         0.157137
# median        67.850000         0.177505
# <lambda>      74.400000         0.177505

# %%
# in this part finding the dispersion of the dataset in which getting the standard deviation and variance of the every columns
measures_of_dispersion = blasting_data.drop(columns=['Time', 'Date']).agg(['std', 'var'])
measures_of_dispersion.head()
# Out:
#        Unnamed: 0  PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)
# std  2.496775e+03     73.507027    7.259741      18.551560    20.433826  \
# var  6.233887e+06   5403.282977   52.703840     344.160386   417.541243
#
#       NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  Ozone (µg/m3)
# std   14.951182    0.542093    59.394849     7.076697      16.337413  \
# var  223.537845    0.293865  3527.748099    50.079640     266.911050
#
#      Benzene (µg/m3)
# std         0.034589
# var         0.001196

# %%
# finding the position of the datset in position getting the minimum and maximum value
min_value=df.min()
max_value=df.max()
min_value.head()
# Out:
# Unnamed: 0                        0
# PM10 (µg/m3)             -13.488183
# Time            2023-07-28 00:00:00
# Date            2023-02-01 00:00:00
# NO (µg/m3)                      0.1
# dtype: object

# %%
max_value.head()
# Out:
# Unnamed: 0                     8639
# PM10 (µg/m3)                  847.0
# Time            2023-07-28 23:45:00
# Date            2023-05-01 00:00:00
# NO (µg/m3)                    157.5
# dtype: object

# %%
measures_of_position = blasting_data.drop(columns=['Time', 'Date']).describe(percentiles=[0.25, 0.5, 0.75])
measures_of_position.head()
# Out:
#         Unnamed: 0  PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)
# count   450.000000    450.000000  450.000000     450.000000   450.000000  \
# mean   4329.000000     97.693250    5.490348      34.181804    47.803924
# std    2496.775337     73.507027    7.259741      18.551560    20.433826
# min      55.000000     15.000000    0.200000       4.000000    12.700000
# 25%    2169.250000     58.250000    3.300000      21.000000    29.500000
#
#         NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  Ozone (µg/m3)
# count  450.000000  450.000000   450.000000   450.000000     450.000000  \
# mean    29.993426    1.055087    51.798855    12.715081      66.428793
# std     14.951182    0.542093    59.394849     7.076697      16.337413
# min      9.700000    0.110000     0.500000     5.100000       8.100000
# 25%     18.225000    0.660000    17.750000     8.700000      60.125000
#
#        Benzene (µg/m3)
# count       450.000000
# mean          0.157137
# std           0.034589
# min           0.100000
# 25%           0.100000

# %%
# getting the scatter plot between PM10 and NO2
plt.figure(figsize=(8, 6))
sns.scatterplot(df, x='PM10 (µg/m3)', y='NO2 (µg/m3)')
plt.xlabel('PM10 (µg/m3)')
plt.ylabel('NO2 (µg/m3)')
plt.title('Scatter plot between PM10 and NO2')
plt.show()

# %%
# finding the correlation between the columns
df.corr()
# Out:
#                  Unnamed: 0  PM10 (µg/m3)          Time          Date
# Unnamed: 0         1.000000     -0.094031  1.111051e-02  9.999383e-01  \
# PM10 (µg/m3)      -0.094031      1.000000 -6.607595e-02 -9.330215e-02
# Time               0.011111     -0.066076  1.000000e+00  7.693855e-11
# Date               0.999938     -0.093302  7.693855e-11  1.000000e+00
# NO (µg/m3)        -0.037397      0.338057 -3.240300e-01 -3.379860e-02
# PM2.5 (µg/m3)     -0.047939      0.519071 -1.788350e-01 -4.595530e-02
# NO2 (µg/m3)       -0.193832      0.111211 -4.073343e-02 -1.933914e-01
# NOX (ppb)         -0.190961      0.376677 -2.448438e-01 -1.882527e-01
# CO (mg/m3)         0.271792      0.237630 -1.532823e-01  2.735121e-01
# SO2 (µg/m3)       -0.049947     -0.066691  6.809631e-02 -5.070630e-02
# NH3 (µg/m3)       -0.612323      0.126787 -5.270375e-02 -6.117750e-01
# Ozone (µg/m3)      0.118347     -0.272115  3.149717e-01  1.148544e-01
# Benzene (µg/m3)   -0.210463      0.333491 -1.580356e-01 -2.087202e-01
#
#                  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  NOX (ppb)
# Unnamed: 0        -0.037397      -0.047939    -0.193832  -0.190961  \
# PM10 (µg/m3)       0.338057       0.519071     0.111211   0.376677
# Time              -0.324030      -0.178835    -0.040733  -0.244844
# Date              -0.033799      -0.045955    -0.193391  -0.188253
# NO (µg/m3)         1.000000       0.589850     0.293774   0.810308
# PM2.5 (µg/m3)      0.589850       1.000000     0.184725   0.528303
# NO2 (µg/m3)        0.293774       0.184725     1.000000   0.721059
# NOX (ppb)          0.810308       0.528303     0.721059   1.000000
# CO (mg/m3)         0.339828       0.413555    -0.075715   0.204010
# SO2 (µg/m3)        0.013893      -0.037140     0.166727   0.066211
# NH3 (µg/m3)        0.010689       0.049492     0.239725   0.222983
# Ozone (µg/m3)     -0.535566      -0.498535    -0.427005  -0.613768
# Benzene (µg/m3)    0.155600       0.367714     0.018227   0.240162
#
#                  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  Ozone (µg/m3)
# Unnamed: 0         0.271792    -0.049947    -0.612323       0.118347  \
# PM10 (µg/m3)       0.237630    -0.066691     0.126787      -0.272115
# Time              -0.153282     0.068096    -0.052704       0.314972
# Date               0.273512    -0.050706    -0.611775       0.114854
# NO (µg/m3)         0.339828     0.013893     0.010689      -0.535566
# PM2.5 (µg/m3)      0.413555    -0.037140     0.049492      -0.498535
# NO2 (µg/m3)       -0.075715     0.166727     0.239725      -0.427005
# NOX (ppb)          0.204010     0.066211     0.222983      -0.613768
# CO (mg/m3)         1.000000    -0.045896    -0.215052      -0.374947
# SO2 (µg/m3)       -0.045896     1.000000    -0.081585       0.070972
# NH3 (µg/m3)       -0.215052    -0.081585     1.000000      -0.081528
# Ozone (µg/m3)     -0.374947     0.070972    -0.081528       1.000000
# Benzene (µg/m3)    0.178914    -0.029167     0.108902      -0.213564
#
#                  Benzene (µg/m3)
# Unnamed: 0             -0.210463
# PM10 (µg/m3)            0.333491
# Time                   -0.158036
# Date                   -0.208720
# NO (µg/m3)              0.155600
# PM2.5 (µg/m3)           0.367714
# NO2 (µg/m3)             0.018227
# NOX (ppb)               0.240162
# CO (mg/m3)              0.178914
# SO2 (µg/m3)            -0.029167
# NH3 (µg/m3)             0.108902
# Ozone (µg/m3)          -0.213564
# Benzene (µg/m3)         1.000000

# %%
# finding the acf_plot for the all columns which is autocorrelation represent
acf_plot= plot_acf(df['PM10 (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['NO2 (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['PM2.5 (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['NO (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['NOX (ppb)'],lags=100)

# %%
acf_plot= plot_acf(df['CO (mg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['SO2 (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['NH3 (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['Ozone (µg/m3)'],lags=100)

# %%
acf_plot= plot_acf(df['Benzene (µg/m3)'],lags=100)

# %%
# finding the pacf_plot for the all columns which is partial autocorrelation represent
pacf_plot=plot_pacf(df['PM10 (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['PM2.5 (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['NO (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['NO2 (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['NH3 (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['SO2 (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['Benzene (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['CO (mg/m3)'])

# %%
pacf_plot=plot_pacf(df['NOX (ppb)'])

# %%
pacf_plot=plot_pacf(df['Benzene (µg/m3)'])

# %%
pacf_plot=plot_pacf(df['Ozone (µg/m3)'])

# %%
# here applying the arima model 
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf,pacf
from datetime import datetime ,timedelta
register_matplotlib_converters()

# %%
from statsmodels.tsa.arima.model import ARIMA
blasting_period_start = '13:45:00'
blasting_period_end = '14:45:00'
df['Time'] = pd.to_datetime(df['Time'])
blasting_data = df[(df['Time'] >= blasting_period_start) & (df['Time'] <= blasting_period_end)]

# Set the 'Time' column as the index
blasting_data.set_index('Time', inplace=True)

# Perform the intervention analysis using ARIMA model
def intervention_analysis(df):
    # Fit an ARIMA model to the data
    model = ARIMA(data, order=(1, 1, 0))
    # (p, d, q) = (1, 1, 0)
    model_fit = model.fit()
    # Get the residuals (differenced data)
    residuals = model_fit.resid

    # Calculate the mean level change after the intervention
    mean_level_change = np.mean(residuals)

    # Plot the original data and the residuals
    plt.figure(figsize=(10, 6))
    plt.subplot(2, 1, 1)
    plt.plot(df, label='Original Data')
    plt.title('Original Data')
    plt.legend()

# %%
#Splits the data into segments before and after the time of blasting
# to show the underlying properties of the source information. It is 
# like categorizing the data into various unifying parts for appropriate inference
blasting_period_start = '13:45:00'
blasting_period_end = '14:45:00'
df['Time'] = pd.to_datetime(df['Time'])

blasting_time_index = df[df['Time'] == blasting_period_start].index[0]

before_blasting = df.iloc[:blasting_time_index + 1]
after_blasting = df.iloc[blasting_time_index:]

print("Segment Before Blasting:")
print(before_blasting)

print("\nSegment After Blasting:")
print(after_blasting)
# Out:
# Segment Before Blasting:
#     Unnamed: 0  PM10 (µg/m3)                Time       Date  NO (µg/m3)
# 0            0          95.0 2023-07-28 00:00:00 2023-02-01   14.484070  \
# 1            1          95.0 2023-07-28 00:15:00 2023-02-01   14.484070
# 2            2          95.0 2023-07-28 00:30:00 2023-02-01   15.835914
# 3            3         122.0 2023-07-28 00:45:00 2023-02-01   15.914518
# 4            4         122.0 2023-07-28 01:00:00 2023-02-01   16.035640
# 5            5         122.0 2023-07-28 01:15:00 2023-02-01   17.497777
# 6            6         122.0 2023-07-28 01:30:00 2023-02-01   17.121285
# 7            7          90.0 2023-07-28 01:45:00 2023-02-01   15.532830
# 8            8          90.0 2023-07-28 02:00:00 2023-02-01   19.465702
# 9            9          90.0 2023-07-28 02:15:00 2023-02-01   22.215146
# 10          10          90.0 2023-07-28 02:30:00 2023-02-01   21.873791
# 11          11          72.0 2023-07-28 02:45:00 2023-02-01   22.263463
# 12          12          72.0 2023-07-28 03:00:00 2023-02-01   18.368449
# 13          13          72.0 2023-07-28 03:15:00 2023-02-01   18.340577
# 14          14          72.0 2023-07-28 03:30:00 2023-02-01   18.937145
# 15          15          72.0 2023-07-28 03:45:00 2023-02-01   21.870167
# 16          16          72.0 2023-07-28 04:00:00 2023-02-01   20.616165
# 17          17          72.0 2023-07-28 04:15:00 2023-02-01   21.526637
# 18          18          72.0 2023-07-28 04:30:00 2023-02-01   21.730734
# 19          19          58.0 2023-07-28 04:45:00 2023-02-01   21.743824
# 20          20          58.0 2023-07-28 05:00:00 2023-02-01   22.402957
# 21          21          58.0 2023-07-28 05:15:00 2023-02-01   23.411493
# 22          22          58.0 2023-07-28 05:30:00 2023-02-01   24.282242
# 23          23          58.0 2023-07-28 05:45:00 2023-02-01   26.114261
# 24          24          58.0 2023-07-28 06:00:00 2023-02-01   28.480500
# 25          25          58.0 2023-07-28 06:15:00 2023-02-01   29.513563
# 26          26          58.0 2023-07-28 06:30:00 2023-02-01   30.911297
# 27          27          67.0 2023-07-28 06:45:00 2023-02-01   32.767534
# 28          28          67.0 2023-07-28 07:00:00 2023-02-01   33.016265
# 29          29          67.0 2023-07-28 07:15:00 2023-02-01   32.269177
# 30          30          67.0 2023-07-28 07:30:00 2023-02-01   30.359115
# 31          31          83.0 2023-07-28 07:45:00 2023-02-01   24.254832
# 32          32          83.0 2023-07-28 08:00:00 2023-02-01   19.264315
# 33          33          83.0 2023-07-28 08:15:00 2023-02-01   21.056062
# 34          34          83.0 2023-07-28 08:30:00 2023-02-01   19.508112
# 35          35         122.0 2023-07-28 08:45:00 2023-02-01   16.918419
# 36          36         122.0 2023-07-28 09:00:00 2023-02-01   15.408915
# 37          37         122.0 2023-07-28 09:15:00 2023-02-01   14.038143
# 38          38         122.0 2023-07-28 09:30:00 2023-02-01   12.374605
# 39          39          99.0 2023-07-28 09:45:00 2023-02-01   11.711007
# 40          40          99.0 2023-07-28 10:00:00 2023-02-01   11.710941
# 41          41          99.0 2023-07-28 10:15:00 2023-02-01    9.043293
# 42          42          99.0 2023-07-28 10:30:00 2023-02-01    7.109905
# 43          43          64.0 2023-07-28 10:45:00 2023-02-01    4.865085
# 44          44          64.0 2023-07-28 11:00:00 2023-02-01    5.082303
# 45          45          64.0 2023-07-28 11:15:00 2023-02-01    5.550451
# 46          46          64.0 2023-07-28 11:30:00 2023-02-01    6.967527
# 47          47          64.0 2023-07-28 11:45:00 2023-02-01    7.090766
# 48          48          64.0 2023-07-28 12:00:00 2023-02-01    4.816976
# 49          49          64.0 2023-07-28 12:15:00 2023-02-01    4.816976
# 50          50          64.0 2023-07-28 12:30:00 2023-02-01    4.816976
# 51          51          61.0 2023-07-28 12:45:00 2023-02-01    4.816976
# 52          52          61.0 2023-07-28 13:00:00 2023-02-01    6.920548
# 53          53          61.0 2023-07-28 13:15:00 2023-02-01    5.172524
# 54          54          61.0 2023-07-28 13:30:00 2023-02-01    4.987132
# 55          55          73.0 2023-07-28 13:45:00 2023-02-01    4.647741
#
#     PM2.5 (µg/m3)  NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)
# 0            35.0    90.100000  56.200000    0.310000    11.986833  \
# 1            35.0    88.000000  55.100000    0.330000    11.986833
# 2            35.0    87.700000  55.200000    0.380000    10.912796
# 3            34.0    88.900000  55.700000    0.380000    10.613291
# 4            34.0    90.000000  55.800000    0.380000     7.362361
# 5            34.0    90.200000  55.900000    0.370000     8.494481
# 6            34.0    88.900000  55.400000    0.340000     8.326684
# 7            35.0    88.900000  55.200000    0.350000     8.612863
# 8            35.0    88.900000  55.900000    0.340000     9.272343
# 9            35.0    88.900000  55.300000    0.350000     9.457114
# 10           35.0    88.800000  55.400000    0.390000     8.161848
# 11           32.0    88.900000  55.100000    0.460000     7.735572
# 12           32.0    88.900000  55.800000    0.470000     7.741644
# 13           32.0    87.700000  55.500000    0.440000     8.054953
# 14           32.0    85.600000  54.200000    0.410000     8.917091
# 15           44.0    84.900000  54.100000    0.410000     8.872507
# 16           44.0    84.500000  53.700000    0.410000     9.676804
# 17           44.0    83.600000  53.000000    0.420000    12.380393
# 18           44.0    82.700000  52.300000    0.390000    16.906199
# 19           28.0    81.300000  51.500000    0.370000    14.528232
# 20           28.0    80.000000  51.200000    0.340000    12.566006
# 21           28.0    80.100000  51.400000    0.330000    17.112551
# 22           28.0    78.900000  51.100000    0.320000    13.342069
# 23           33.0    78.600000  50.600000    0.320000    14.105962
# 24           33.0    79.300000  49.900000    0.310000    14.064054
# 25           33.0    77.900000  49.500000    0.310000    12.988856
# 26           33.0    76.700000  49.000000    0.310000    12.234778
# 27           45.0    75.700000  48.600000    0.330000    13.274928
# 28           45.0    76.100000  49.000000    0.370000    13.965676
# 29           45.0    76.300000  49.000000    0.450000    14.583896
# 30           45.0    75.900000  48.900000    0.520000    14.899626
# 31           68.0    76.600000  49.300000    0.470000    21.080541
# 32           68.0    79.100000  50.800000    0.490000    19.599870
# 33           68.0    78.900000  50.600000    0.340000    14.425674
# 34           68.0    77.800000  49.100000    0.290000    13.840201
# 35           46.0    79.100000  48.900000    0.260000    17.268854
# 36           46.0    80.400000  48.600000    0.260000    18.956674
# 37           46.0    81.100000  48.100000    0.260000    21.631572
# 38           46.0    82.100000  47.700000    0.260000    34.454267
# 39           31.0    80.400000  46.700000    1.106427    42.650596
# 40           31.0    77.900000  45.500000    1.100000    54.249871
# 41           31.0    77.400000  45.100000    1.100000    44.955366
# 42           31.0    76.000000  44.300000    0.270000    48.422375
# 43           22.0    75.100000  44.200000    0.250000    50.929625
# 44           22.0    75.400000  43.800000    0.240000    59.562409
# 45           22.0    74.900000  42.900000    0.230000    59.562409
# 46           22.0    73.200000  41.600000    0.220000    59.562409
# 47           23.0    66.890076  35.862208    0.140000    59.562409
# 48           23.0    64.000000  36.400000    0.150000    54.114944
# 49           23.0    64.000000  36.400000    0.310000    36.614458
# 50           23.0    64.000000  36.400000    0.290000    46.753613
# 51           23.0    62.100000  35.100000    0.270000    66.836173
# 52           23.0    63.600000  35.900000    0.240000    51.757819
# 53           23.0    63.400000  35.900000    0.100000    51.126300
# 54           23.0    61.500000  35.200000    0.230000    61.667211
# 55           18.0    59.900000  34.800000    0.310000    49.421488
#
#     NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)
# 0     17.700000      28.100000              0.4
# 1     18.300000      27.100000              0.4
# 2     19.700000      24.900000              0.4
# 3     21.300000      21.900000              0.4
# 4     22.300000      16.700000              0.4
# 5     22.700000      16.100000              0.4
# 6     23.100000      22.500000              0.4
# 7     23.500000      20.500000              0.4
# 8     23.100000      22.800000              0.4
# 9     22.900000      19.000000              0.4
# 10    22.600000      17.100000              0.4
# 11    22.500000      19.100000              0.4
# 12    22.700000      18.200000              0.4
# 13    22.500000      18.000000              0.4
# 14    22.700000      15.700000              0.4
# 15    23.200000      13.800000              0.4
# 16    23.400000      16.400000              0.4
# 17    21.300000      16.900000              0.4
# 18    19.900000      16.700000              0.4
# 19    18.800000      18.900000              0.4
# 20    18.300000      22.800000              0.4
# 21    17.300000      22.700000              0.4
# 22    17.200000      23.700000              0.4
# 23    17.700000      24.100000              0.4
# 24    17.600000      22.400000              0.4
# 25    17.500000      17.500000              0.4
# 26    18.000000      15.800000              0.4
# 27    18.200000      14.000000              0.4
# 28    18.000000      11.000000              0.4
# 29    19.100000       9.300000              0.4
# 30    18.800000      12.500000              0.4
# 31    18.100000      22.100000              0.4
# 32    17.300000      30.100000              0.4
# 33    18.200000      35.800000              0.4
# 34    20.400000      36.900000              0.4
# 35    21.700000      39.702176              0.4
# 36    23.200000      44.500000              0.4
# 37    23.400000      44.500000              0.4
# 38    22.400000      44.600000              0.4
# 39    23.700000      45.800000              0.4
# 40    25.100000      47.300000              0.4
# 41    27.000000      48.600000              0.4
# 42    28.200000      49.200000              0.2
# 43    26.600000      50.400000              0.1
# 44    25.800000      51.700000              0.1
# 45    24.800000      53.400000              0.1
# 46    24.900000      52.100000              0.1
# 47     8.726567      59.227880              0.1
# 48    24.000000      60.378912              0.1
# 49    24.000000      61.146220              0.1
# 50    24.000000      63.112761              0.1
# 51    21.900000      58.600000              0.1
# 52    20.600000      59.800000              0.1
# 53    20.100000      57.100000              0.1
# 54    20.400000      56.500000              0.1
# 55    20.500000      56.900000              0.1
#
# Segment After Blasting:
#       Unnamed: 0  PM10 (µg/m3)                Time       Date  NO (µg/m3)
# 55            55          73.0 2023-07-28 13:45:00 2023-02-01    4.647741  \
# 56            56          73.0 2023-07-28 14:00:00 2023-02-01    4.854775
# 57            57          73.0 2023-07-28 14:15:00 2023-02-01    5.469984
# 58            58          73.0 2023-07-28 14:30:00 2023-02-01    5.736887
# 59            59          63.0 2023-07-28 14:45:00 2023-02-01    6.123021
# ...          ...           ...                 ...        ...         ...
# 8635        8635          19.0 2023-07-28 22:45:00 2023-05-01   17.900000
# 8636        8636          19.0 2023-07-28 23:00:00 2023-05-01   17.900000
# 8637        8637          19.0 2023-07-28 23:15:00 2023-05-01   19.600000
# 8638        8638          19.0 2023-07-28 23:30:00 2023-05-01   20.800000
# 8639        8639          32.0 2023-07-28 23:45:00 2023-05-01   21.800000
#
#       PM2.5 (µg/m3)  NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)
# 55             18.0         59.9       34.8    0.310000    49.421488  \
# 56             18.0         62.4       36.2    0.300000    53.211752
# 57             18.0         61.1       35.0    0.310000    36.971376
# 58             18.0         59.0       34.0    0.340000    29.556898
# 59             14.0         59.2       34.0    0.380000    27.448166
# ...             ...          ...        ...         ...          ...
# 8635           11.0        100.0       67.8    0.630000    10.000000
# 8636           11.0        100.0       67.7    0.570000    10.000000
# 8637           11.0        100.2       69.2    0.580000     9.900000
# 8638           11.0        100.2       70.2    0.580000     9.500000
# 8639            6.0         98.8       70.3    0.883181    13.054913
#
#       NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)
# 55           20.5           56.9              0.1
# 56           20.7           56.8              0.1
# 57           21.5           57.1              0.1
# 58           22.0           55.0              0.1
# 59           20.8           56.3              0.1
# ...           ...            ...              ...
# 8635         10.7           26.1              0.1
# 8636         10.4           30.9              0.1
# 8637         10.5           29.6              0.1
# 8638         10.8           30.0              0.1
# 8639         11.0           33.5              0.1
#
# [8585 rows x 13 columns]
